# %%
# Out:
# Hello

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
a = [7,8,9,10,11]
b = [20,30,40,50,70]

# %%
plt.plot(a,b)
plt.title("Student hrs vs marks")
plt.xlabel("Hrs")
plt.ylabel("Marks")
plt.show()

# %%
subject = ["M1", "M2", "Chem", "Physics"]
marks = ["15", "19", "11", "16"]
plt.bar(subject, marks)
plt.title("Student subject vs marks")
plt.xlabel("SUB")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt

contributers = ["aditya","krishna","krish","aman"]
work_done = [34, 10, 35, 21]   # numbers as integers

work_done.sort()   

plt.bar(contributers, work_done)
plt.title("Work done by people")
plt.xlabel("People")
plt.ylabel("Percentage")
plt.show()

# %%
pip install pyttsx3
# Out:
# ...
#
# ...

# %%
import pyttsx3

# %%
speaker = pyttsx3.init()
speaker.say("Hello Mansimran Singh")
speaker.runAndWait()

# %%
pip install SpeechRecognition
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyAudio

# %%
import speech_recognition as sr

# %%
mic = sr.Recognizer()

# %%
speaker = pyttsx3.init()

speaker.say("Welcome to Jarvis")
speaker.runAndWait()
with sr.Microphone() as source:
    print("Start Speaking...")
    voice = mic.listen(source)
    text = mic.recognize_google(voice)
if "open notepad" in text:
    print("Opening Notepad...")
    os.system("notepad")
# Out:
# Start Speaking...

# %%
pip install pywhatkit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pywhatkit

# %%
pywhatkit.sendwhatmsg_instantly("+919079551467", "Hi I am from VGU")

# %%
# Out:
# In 43 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!

# %%
import webbrowser

# %%
import os

# %%
os.startfile("C:/Users/Admin/Documents/vgu-python/PyWhatKit_DB.txt")

# %%
import matplotlib.pyplot as plt
import pyttsx3
import speech_recognition as sr
import pywhatkit
import webbrowser
import os

speaker = pyttsx3.init()
mic = sr.Recognizer()

speaker.say("Welcome to jarvis")
speaker.runAndWait()
with sr.Microphone() as source:
    print("Start Speaking...")
    voice = mic.listen(source)
    text = mic.recognize_google(voice)
if "open notepad" in text:
    print("Opening Notepad...")
    os.system("notepad")
